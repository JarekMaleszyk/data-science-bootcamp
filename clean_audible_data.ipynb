# %% [markdown]
# <a href="https://colab.research.google.com/github/JarekMaleszyk/data-science-bootcamp/blob/master/clean_audible_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
RAW_FILE_PATH = '/content/audible/audible_raw.csv'

try:
  audible = pd.read_csv(RAW_FILE_PATH, header=0)
except FileNotFoundError as e:
  print(e)

# %%
audible.author = audible.author.str.replace('Writtenby:', '')
audible.author = audible.author.str.replace(r"([A-Z])", r" \1", regex=True).str.strip()
audible.narrator = audible.narrator.str.replace('Narratedby:', '')
audible.narrator = audible.narrator.str.replace(r"([A-Z])", r" \1", regex=True).str.strip()

# %%
audible.stars.replace('Not rated yet', np.nan, inplace=True)

# %%
audible['releaseyear'] = audible.releasedate.str[-2:].astype(int)
audible['releaseyear'] = audible['releaseyear'].apply(lambda x: 2000 + x if x < 50 else 1900 + x) #apply
audible['releasemonth'] = audible.releasedate.str[3:5].astype(int)
audible['releaseday'] = audible.releasedate.str[0:2].astype(int)

# %%
audible['releasedate'] = pd.to_datetime((audible.releaseyear*10000+audible.releasemonth*100+audible.releaseday).apply(str),format='%Y%m%d')

# %%
audible.drop(['releaseday', 'releasemonth', 'releaseyear'], axis=1, inplace=True)

# %%
audible['timehours'] = audible.time.str.extract(r'(\d+) hr').fillna(0).astype(int)
audible['timemins'] = audible.time.str.extract(r'(\d+) min').fillna(0).astype(int)

# %%
audible
# Out:
#                                              name            author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps   Stephen O' Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#               narrator                time releasedate language  \
# 0          Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1       Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2          Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3      Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4      Jesse Bernstein              10 hrs  2010-01-13  English
# ...                ...                 ...         ...      ...
# 87484    Chris Stewart   7 hrs and 34 mins  2017-03-09  English
# 87485      Robert Fass   10 hrs and 7 mins  2017-02-21  English
# 87486       Flo Gibson   19 hrs and 4 mins  2016-12-30  English
# 87487     Anton Lesser    4 hrs and 8 mins  2011-02-23  English
# 87488     Fleet Cooper     6 hrs and 1 min  2017-03-07  English
#
#                                stars   price  timehours  timemins
# 0         5 out of 5 stars34 ratings  468.00          2        20
# 1       4.5 out of 5 stars41 ratings  820.00         13         8
# 2       4.5 out of 5 stars38 ratings  410.00          2         3
# 3       4.5 out of 5 stars12 ratings  615.00         11        16
# 4      4.5 out of 5 stars181 ratings  820.00         10         0
# ...                              ...     ...        ...       ...
# 87484                            NaN  596.00          7        34
# 87485                            NaN  820.00         10         7
# 87486                            NaN  938.00         19         4
# 87487                            NaN  680.00          4         8
# 87488                            NaN  569.00          6         1
#
# [87489 rows x 10 columns]
