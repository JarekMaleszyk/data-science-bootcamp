# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/data-science-bootcamp/blob/master/02_analiza_danych/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Pandas
# Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
#
# Podstawowa biblioteka do analizy danych w języku Python.
#
# Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych](#a2)
# 3. [Preprocessing](#a3)
# 4. [Konkatenacja danych](#a4)
# 5. [Metoda append()](#a5)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.1'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1221 entries, 2024-03-15 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1221 non-null   float64
#  1   High    1221 non-null   float64
#  2   Low     1221 non-null   float64
#  3   Close   1221 non-null   float64
#  4   Volume  1221 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 57.2 KB

# %%
apple.head()
# Out:
#               Open      High      Low   Close       Volume
# Date
# 2024-03-15  171.17  172.6200  170.285  172.62  121752699.0
# 2024-03-14  172.91  174.3078  172.050  173.00   72913507.0
# 2024-03-13  172.77  173.1850  170.760  171.13   52488692.0
# 2024-03-12  173.15  174.0300  171.010  173.23   59825372.0
# 2024-03-11  172.94  174.3800  172.050  172.75   60139473.0

# %% [markdown]
# ### <a name='a3'></a> Preprocessing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns] #dodanie przedrostka i zamiana na małe
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-03-15      171.17    172.6200    170.285       172.62   121752699.0
# 2024-03-14      172.91    174.3078    172.050       173.00    72913507.0
# 2024-03-13      172.77    173.1850    170.760       171.13    52488692.0
# 2024-03-12      173.15    174.0300    171.010       173.23    59825372.0
# 2024-03-11      172.94    174.3800    172.050       172.75    60139473.0

# %% [markdown]
# ### <a name='a4'></a> Konkatenacja danych

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1) #łączy wszystkie tabele po 1 osi
df
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume  \
# Date
# 2019-03-19     45.6448     45.8013    45.0526      45.2011  1.305927e+08
# 2019-03-20     45.1293     45.9209    44.7634      45.5980  1.280708e+08
# 2019-03-21     46.0445     47.5769    45.9957      47.2728  2.105991e+08
# 2019-03-22     47.3346     47.9038    46.2290      46.2958  1.750005e+08
# 2019-03-25     46.4104     46.5221    45.2191      45.7415  1.809331e+08
# amazon_open        132.21       159.70       187.20
# amazon_high        133.57       161.44       188.65
# amazon_low         130.54       157.75       184.84
# amazon_close       132.13       159.52       186.57
# amazon_volume 64234060.00  85711495.00 311345660.00
# google_open        103.10       129.84       152.80
# google_high        104.81       131.51       153.78
# google_low         102.07       128.30       151.43
# google_close       103.72       129.76       153.51
# google_volume 29897280.00  37735151.75 133177100.00
# uber_open           37.39        46.26        81.94
# uber_high           37.99        47.09        82.14
# uber_low            36.58        45.60        80.79
# uber_close          37.21        46.29        81.39
# uber_volume   21213042.00  29454687.00 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.50
# apple_high           1.00        1.00       1.00         1.00         -0.50
# apple_low            1.00        1.00       1.00         1.00         -0.51
# apple_close          1.00        1.00       1.00         1.00         -0.51
# apple_volume        -0.50       -0.50      -0.51        -0.51          1.00
# amazon_open          0.53        0.53       0.53         0.53         -0.12
# amazon_high          0.53        0.53       0.53         0.53         -0.12
# amazon_low           0.53        0.52       0.53         0.52         -0.13
# amazon_close         0.53        0.53       0.53         0.53         -0.13
# amazon_volume       -0.29       -0.28      -0.30        -0.29          0.61
# google_open          0.90        0.90       0.90         0.90         -0.50
# google_high          0.90        0.90       0.90         0.90         -0.50
# google_low           0.90        0.90       0.90         0.90         -0.51
# google_close         0.90        0.90       0.90         0.90         -0.51
# google_volume       -0.09       -0.09      -0.10        -0.10          0.45
# uber_open            0.32        0.32       0.33         0.32         -0.28
# uber_high            0.32        0.32       0.33         0.32         -0.27
# uber_low             0.33        0.32       0.33         0.33         -0.29
# uber_close           0.33        0.32       0.33         0.33         -0.28
# uber_volume          0.06        0.06       0.06         0.06          0.20
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.53         0.53        0.53          0.53
# apple_high            0.53         0.53        0.52          0.53
# apple_low             0.53         0.53        0.53          0.53
# apple_close           0.53         0.53        0.52          0.53
# apple_volume         -0.12        -0.12       -0.13         -0.13
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.11        -0.09       -0.12         -0.11
# google_open           0.66         0.66        0.66          0.66
# google_high           0.66         0.66        0.66          0.66
# google_low            0.66         0.66        0.66          0.66
# google_close          0.66         0.66        0.66          0.66
# google_volume        -0.10        -0.09       -0.11         -0.11
# uber_open             0.59         0.58        0.60          0.59
# uber_high             0.59         0.59        0.60          0.59
# uber_low              0.59         0.58        0.60          0.59
# uber_close            0.59         0.58        0.60          0.59
# uber_volume          -0.03        -0.02       -0.03         -0.03
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.29         0.90         0.90        0.90
# apple_high             -0.28         0.90         0.90        0.90
# apple_low              -0.30         0.90         0.90        0.90
# apple_close            -0.29         0.90         0.90        0.90
# apple_volume            0.61        -0.50        -0.50       -0.51
# amazon_open            -0.11         0.66         0.66        0.66
# amazon_high            -0.09         0.66         0.66        0.66
# amazon_low             -0.12         0.66         0.66        0.66
# amazon_close           -0.11         0.66         0.66        0.66
# amazon_volume           1.00        -0.32        -0.31       -0.32
# google_open            -0.32         1.00         1.00        1.00
# google_high            -0.31         1.00         1.00        1.00
# google_low             -0.32         1.00         1.00        1.00
# google_close           -0.32         1.00         1.00        1.00
# google_volume           0.54        -0.14        -0.14       -0.16
# uber_open              -0.28         0.43         0.42        0.43
# uber_high              -0.28         0.43         0.42        0.43
# uber_low               -0.30         0.43         0.43        0.44
# uber_close             -0.29         0.43         0.42        0.43
# uber_volume             0.22         0.05         0.05        0.04
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.90          -0.09       0.32       0.32      0.33
# apple_high             0.90          -0.09       0.32       0.32      0.32
# apple_low              0.90          -0.10       0.33       0.33      0.33
# apple_close            0.90          -0.10       0.32       0.32      0.33
# apple_volume          -0.51           0.45      -0.28      -0.27     -0.29
# amazon_open            0.66          -0.10       0.59       0.59      0.59
# amazon_high            0.66          -0.09       0.58       0.59      0.58
# amazon_low             0.66          -0.11       0.60       0.60      0.60
# amazon_close           0.66          -0.11       0.59       0.59      0.59
# amazon_volume         -0.32           0.54      -0.28      -0.28     -0.30
# google_open            1.00          -0.14       0.43       0.43      0.43
# google_high            1.00          -0.14       0.42       0.42      0.43
# google_low             1.00          -0.16       0.43       0.43      0.44
# google_close           1.00          -0.15       0.43       0.43      0.43
# google_volume         -0.15           1.00      -0.15      -0.15     -0.17
# uber_open              0.43          -0.15       1.00       1.00      1.00
# uber_high              0.43          -0.15       1.00       1.00      1.00
# uber_low               0.43          -0.17       1.00       1.00      1.00
# uber_close             0.43          -0.16       1.00       1.00      1.00
# uber_volume            0.05           0.23      -0.12      -0.11     -0.14
#
#                uber_close  uber_volume
# apple_open           0.33         0.06
# apple_high           0.32         0.06
# apple_low            0.33         0.06
# apple_close          0.33         0.06
# apple_volume        -0.28         0.20
# amazon_open          0.59        -0.03
# amazon_high          0.58        -0.02
# amazon_low           0.60        -0.03
# amazon_close         0.59        -0.03
# amazon_volume       -0.29         0.22
# google_open          0.43         0.05
# google_high          0.42         0.05
# google_low           0.43         0.04
# google_close         0.43         0.05
# google_volume       -0.16         0.23
# uber_open            1.00        -0.12
# uber_high            1.00        -0.11
# uber_low             1.00        -0.14
# uber_close           1.00        -0.12
# uber_volume         -0.12         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0.53          0.90        0.33
# amazon_close         0.53          1.00          0.66        0.59
# google_close         0.90          0.66          1.00        0.43
# uber_close           0.33          0.59          0.43        1.00

# %%
closes = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.51          0.53          -0.29
# apple_volume         -0.51          1.00         -0.13           0.61
# amazon_close          0.53         -0.13          1.00          -0.11
# amazon_volume        -0.29          0.61         -0.11           1.00
# google_close          0.90         -0.51          0.66          -0.32
# google_volume        -0.10          0.45         -0.11           0.54
# uber_close            0.33         -0.28          0.59          -0.29
# uber_volume           0.06          0.20         -0.03           0.22
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.90          -0.10        0.33         0.06
# apple_volume          -0.51           0.45       -0.28         0.20
# amazon_close           0.66          -0.11        0.59        -0.03
# amazon_volume         -0.32           0.54       -0.29         0.22
# google_close           1.00          -0.15        0.43         0.05
# google_volume         -0.15           1.00       -0.16         0.23
# uber_close             0.43          -0.16        1.00        -0.12
# uber_volume            0.05           0.23       -0.12         1.00

# %% [markdown]
# ### <a name='a5'></a> Metoda append()

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-03-15      77.00      77.84     75.77       76.07     24554947
# 2024-03-14      78.34      78.48     76.90       77.65     12737226
# 2024-03-13      78.00      79.69     77.93       78.25     12065099
# 2024-03-12      78.01      78.48     77.48       78.32     11303824
# 2024-03-11      78.70      78.89     76.53       77.47     13781394

# %%
uber_6 = uber[(uber.index.month == 6) & (uber.index.year == 2019)]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2019-06-28      45.10      47.08     45.08       46.38     28657002
# 2019-06-27      43.35      45.30     43.20       45.13     20155079
# 2019-06-26      43.25      43.40     42.36       42.50      8109056
# 2019-06-25      43.28      43.79     42.44       43.09      5755107
# 2019-06-24      44.00      44.07     42.82       43.09      5985052
# 2019-06-21      43.85      44.14     43.38       44.00      4973987
# 2019-06-20      45.03      45.29     43.51       43.86      9567367
# 2019-06-19      44.46      45.50     43.95       44.86     10331520
# 2019-06-18      44.30      44.89     43.75       43.86      7313602
# 2019-06-17      43.28      44.08     42.93       43.78      6557589
# 2019-06-14      44.75      44.80     43.11       43.23      7902223
# 2019-06-13      43.05      44.35     42.80       44.31     10178935
# 2019-06-12      42.52      42.65     41.71       42.17      5965250
# 2019-06-11      43.22      43.65     41.80       42.45      9095044
# 2019-06-10      44.02      44.59     42.53       42.61     11618701
# 2019-06-07      44.92      45.67     44.13       44.16     12654670
# 2019-06-06      45.00      45.75     44.28       44.92     16403691
# 2019-06-05      42.87      45.66     42.50       45.00     28609604
# 2019-06-04      42.56      42.88     40.70       42.75     23432141
# 2019-06-03      40.74      41.85     40.24       41.25     16605261

# %%
uber_7 = uber[(uber.index.month == 7) & (uber.index.year == 2019)]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2019-07-31      42.60      42.98     41.84       42.14      5970774
# 2019-07-30      43.71      43.74     42.49       42.59      7686342
# 2019-07-29      45.00      45.63     43.12       43.88      8652204
# 2019-07-26      43.42      44.96     43.39       44.52      7598828
# 2019-07-25      43.72      43.96     43.21       43.40      4411991
# 2019-07-24      43.36      43.87     43.36       43.76      3775677
# 2019-07-23      43.75      44.31     43.11       43.36      5110090
# 2019-07-22      43.25      43.72     43.01       43.69      3822276
# 2019-07-19      43.90      44.09     43.16       43.18      4021018
# 2019-07-18      43.50      43.85     43.19       43.71      4123615
