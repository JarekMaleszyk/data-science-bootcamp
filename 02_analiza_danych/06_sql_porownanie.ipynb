# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/data-science-bootcamp/blob/master/02_analiza_danych/06_sql_porownanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Pandas
# >Strona biblioteki: [https://pandas.pydata.org/](https://pandas.pydata.org/)
# >Dokumentacja: [https://pandas.pydata.org/pandas-docs/stable/](https://pandas.pydata.org/pandas-docs/stable/)
# >
# >Podstawowa biblioteka do analizy danych w języku Python.
# >
# >Aby zainstalować bibliotekę Pandas użyj polecenia poniżej:
# ```
# pip install pandas
# ```
# ### Spis treści:
# 1. [Import bibliotek](#a1)
# 2. [Wczytanie danych i preprocessing](#a2)
# 3. [Porównanie do języka SQL](#a3)

# %% [markdown]
# ### <a name='a1'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '2.2.1'

# %% [markdown]
# ### <a name='a2'></a> Wczytanie danych i preprocessing

# %%
url = ('https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/online_retail.xlsx')
retail_raw = pd.read_excel(url)
retail_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail = retail_raw.copy()
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
retail.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail = retail.dropna()
retail.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
retail = retail[retail.Quantity >= 0]
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  object
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.3+ MB

# %%
retail.CustomerID = retail.CustomerID.apply(lambda x: str(int(x)))
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397924 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   InvoiceNo       397924 non-null  object
#  1   StockCode       397924 non-null  object
#  2   Description     397924 non-null  object
#  3   Quantity        397924 non-null  int64
#  4   InvoiceDate     397924 non-null  datetime64[ns]
#  5   UnitPrice       397924 non-null  float64
#  6   CustomerID      397924 non-null  object
#  7   Country         397924 non-null  object
#  8   Revenue         397924 non-null  float64
#  9   InvoiceDateDay  397924 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(1), object(5)
# memory usage: 31.9+ MB

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
#
#    InvoiceDateDay
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# ### <a name='a3'></a> Porównanie do języka SQL

# %%
# SELECT * FROM retial;
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85      12680          France
# 541905 2011-12-09 12:50:00       2.10      12680          France
# 541906 2011-12-09 12:50:00       4.15      12680          France
# 541907 2011-12-09 12:50:00       4.15      12680          France
# 541908 2011-12-09 12:50:00       4.95      12680          France
#
# [397924 rows x 8 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retial;
retail[['Quantity', 'UnitPrice', 'CustomerID']]
# Out:
#         Quantity  UnitPrice CustomerID
# 0              6       2.55      17850
# 1              6       3.39      17850
# 2              8       2.75      17850
# 3              6       3.39      17850
# 4              6       3.39      17850
# ...          ...        ...        ...
# 541904        12       0.85      12680
# 541905         6       2.10      12680
# 541906         4       4.15      12680
# 541907         4       4.15      12680
# 541908         3       4.95      12680
#
# [397924 rows x 3 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retial LIMIT 10;
retail[['Quantity', 'UnitPrice', 'CustomerID']].head(10)
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55      17850
# 1         6       3.39      17850
# 2         8       2.75      17850
# 3         6       3.39      17850
# 4         6       3.39      17850
# 5         2       7.65      17850
# 6         6       4.25      17850
# 7         6       1.85      17850
# 8         6       1.85      17850
# 9        32       1.69      13047

# %%
retail[['Quantity', 'UnitPrice', 'CustomerID']][:10]
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55      17850
# 1         6       3.39      17850
# 2         8       2.75      17850
# 3         6       3.39      17850
# 4         6       3.39      17850
# 5         2       7.65      17850
# 6         6       4.25      17850
# 7         6       1.85      17850
# 8         6       1.85      17850
# 9        32       1.69      13047

# %%
# SELECT * FROM retial WHERE CustomerID='17850';
retail[retail.CustomerID == '17850']
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4540    536790     22752         SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803             IVORY EMBROIDERED QUILT          3
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country
# 0    2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1    2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2    2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3    2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4    2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                  ...        ...        ...             ...
# 4540 2010-12-02 15:26:00       7.65      17850  United Kingdom
# 4541 2010-12-02 15:26:00      35.75      17850  United Kingdom
# 4542 2010-12-02 15:26:00       4.25      17850  United Kingdom
# 4543 2010-12-02 15:27:00       1.85      17850  United Kingdom
# 4544 2010-12-02 15:27:00       1.85      17850  United Kingdom
#
# [297 rows x 8 columns]

# %%
retail.query('CustomerID == "17850"') #funkcja query
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4540    536790     22752         SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803             IVORY EMBROIDERED QUILT          3
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country
# 0    2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1    2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2    2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3    2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4    2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                  ...        ...        ...             ...
# 4540 2010-12-02 15:26:00       7.65      17850  United Kingdom
# 4541 2010-12-02 15:26:00      35.75      17850  United Kingdom
# 4542 2010-12-02 15:26:00       4.25      17850  United Kingdom
# 4543 2010-12-02 15:27:00       1.85      17850  United Kingdom
# 4544 2010-12-02 15:27:00       1.85      17850  United Kingdom
#
# [297 rows x 8 columns]

# %%
# SELECT * FROM retial WHERE CustomerID='17850' and UnitPrice > 5;
retail[(retail.CustomerID == '17850') & (retail.UnitPrice > 5)]
# Out:
#      InvoiceNo StockCode                        Description  Quantity  \
# 5       536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 58      536373     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 63      536373     22752       SET 7 BABUSHKA NESTING BOXES         2
# 75      536375     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 80      536375     22752       SET 7 BABUSHKA NESTING BOXES         2
# 288     536396     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 293     536396     22752       SET 7 BABUSHKA NESTING BOXES         2
# 294     536396     22803           IVORY EMBROIDERED QUILT          2
# 425     536406     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 430     536406     22752       SET 7 BABUSHKA NESTING BOXES         2
# 431     536406     22803           IVORY EMBROIDERED QUILT          2
# 3121    536600     82486  WOOD S/3 CABINET ANT WHITE FINISH         2
# 3127    536600     22752       SET 7 BABUSHKA NESTING BOXES         2
# 3128    536600     22803           IVORY EMBROIDERED QUILT          2
# 3141    536602     22752       SET 7 BABUSHKA NESTING BOXES         2
# 3200    536609     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 3206    536609     22752       SET 7 BABUSHKA NESTING BOXES         2
# 3232    536612     82486  WOOD S/3 CABINET ANT WHITE FINISH         2
# 3433    536628     82486  WOOD S/3 CABINET ANT WHITE FINISH         2
# 3439    536628     22752       SET 7 BABUSHKA NESTING BOXES         2
# 3451    536630     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 3457    536630     22752       SET 7 BABUSHKA NESTING BOXES         2
# 3805    536685     22752       SET 7 BABUSHKA NESTING BOXES         4
# 3806    536685     22803           IVORY EMBROIDERED QUILT          2
# 3816    536685     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 3831    536690     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 3837    536690     22752       SET 7 BABUSHKA NESTING BOXES         4
# 3838    536690     22803           IVORY EMBROIDERED QUILT          2
# 4171    536750     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 4177    536750     22752       SET 7 BABUSHKA NESTING BOXES         4
# 4178    536750     22803           IVORY EMBROIDERED QUILT          2
# 4192    536752     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 4198    536752     22752       SET 7 BABUSHKA NESTING BOXES         4
# 4199    536752     22803           IVORY EMBROIDERED QUILT          2
# 4521    536787     22752       SET 7 BABUSHKA NESTING BOXES         2
# 4535    536790     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 4540    536790     22752       SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803           IVORY EMBROIDERED QUILT          3
#
#              InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 5    2010-12-01 08:26:00       7.65      17850  United Kingdom    15.30
# 58   2010-12-01 09:02:00       6.95      17850  United Kingdom    27.80
# 63   2010-12-01 09:02:00       7.65      17850  United Kingdom    15.30
# 75   2010-12-01 09:32:00       6.95      17850  United Kingdom    27.80
# 80   2010-12-01 09:32:00       7.65      17850  United Kingdom    15.30
# 288  2010-12-01 10:51:00       6.95      17850  United Kingdom    27.80
# 293  2010-12-01 10:51:00       7.65      17850  United Kingdom    15.30
# 294  2010-12-01 10:51:00      35.75      17850  United Kingdom    71.50
# 425  2010-12-01 11:33:00       6.95      17850  United Kingdom    27.80
# 430  2010-12-01 11:33:00       7.65      17850  United Kingdom    15.30
# 431  2010-12-01 11:33:00      35.75      17850  United Kingdom    71.50
# 3121 2010-12-02 08:32:00       6.95      17850  United Kingdom    13.90
# 3127 2010-12-02 08:32:00       7.65      17850  United Kingdom    15.30
# 3128 2010-12-02 08:32:00      35.75      17850  United Kingdom    71.50
# 3141 2010-12-02 08:34:00       7.65      17850  United Kingdom    15.30
# 3200 2010-12-02 09:41:00       6.95      17850  United Kingdom    27.80
# 3206 2010-12-02 09:41:00       7.65      17850  United Kingdom    15.30
# 3232 2010-12-02 09:44:00       6.95      17850  United Kingdom    13.90
# 3433 2010-12-02 10:54:00       6.95      17850  United Kingdom    13.90
# 3439 2010-12-02 10:54:00       7.65      17850  United Kingdom    15.30
# 3451 2010-12-02 10:56:00       6.95      17850  United Kingdom    27.80
# 3457 2010-12-02 10:56:00       7.65      17850  United Kingdom    15.30
# 3805 2010-12-02 12:23:00       7.65      17850  United Kingdom    30.60
# 3806 2010-12-02 12:23:00      35.75      17850  United Kingdom    71.50
# 3816 2010-12-02 12:23:00       6.95      17850  United Kingdom    27.80
# 3831 2010-12-02 12:25:00       6.95      17850  United Kingdom    27.80
# 3837 2010-12-02 12:25:00       7.65      17850  United Kingdom    30.60
# 3838 2010-12-02 12:25:00      35.75      17850  United Kingdom    71.50
# 4171 2010-12-02 14:04:00       6.95      17850  United Kingdom    27.80
# 4177 2010-12-02 14:04:00       7.65      17850  United Kingdom    30.60
# 4178 2010-12-02 14:04:00      35.75      17850  United Kingdom    71.50
# 4192 2010-12-02 14:06:00       6.95      17850  United Kingdom    27.80
# 4198 2010-12-02 14:06:00       7.65      17850  United Kingdom    30.60
# 4199 2010-12-02 14:06:00      35.75      17850  United Kingdom    71.50
# 4521 2010-12-02 15:24:00       7.65      17850  United Kingdom    15.30
# 4535 2010-12-02 15:26:00       6.95      17850  United Kingdom    27.80
# 4540 2010-12-02 15:26:00       7.65      17850  United Kingdom    30.60
# 4541 2010-12-02 15:26:00      35.75      17850  United Kingdom   107.25
#
#       InvoiceDateDay
# 5                  1
# 58                 1
# 63                 1
# 75                 1
# 80                 1
# 288                1
# 293                1
# 294                1
# 425                1
# 430                1
# 431                1
# 3121               2
# 3127               2
# 3128               2
# 3141               2
# 3200               2
# 3206               2
# 3232               2
# 3433               2
# 3439               2
# 3451               2
# 3457               2
# 3805               2
# 3806               2
# 3816               2
# 3831               2
# 3837               2
# 3838               2
# 4171               2
# 4177               2
# 4178               2
# 4192               2
# 4198               2
# 4199               2
# 4521               2
# 4535               2
# 4540               2
# 4541               2

# %%
# SELECT * FROM retial WHERE CustomerID='17850' or Country='France';
retail[(retail.CustomerID == '17850') | (retail.Country == 'France')]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85      12680          France
# 541905 2011-12-09 12:50:00       2.10      12680          France
# 541906 2011-12-09 12:50:00       4.15      12680          France
# 541907 2011-12-09 12:50:00       4.15      12680          France
# 541908 2011-12-09 12:50:00       4.95      12680          France
#
# [8639 rows x 8 columns]

# %%
# SELECT * FROM retail WHERE InvoiceNo is not null;
retail[retail.InvoiceNo.notnull()]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85      12680          France
# 541905 2011-12-09 12:50:00       2.10      12680          France
# 541906 2011-12-09 12:50:00       4.15      12680          France
# 541907 2011-12-09 12:50:00       4.15      12680          France
# 541908 2011-12-09 12:50:00       4.95      12680          France
#
# [397924 rows x 8 columns]

# %%
# SELECT CustomerID, count(*) FROM retial GROUP BY CustomerID;
retail.groupby('CustomerID').size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # SELECT CustomerID, count(*) FROM retial GROUP BY CustomerID;
# ----> 2 retail.groupby('CustomerID').size().sort_values(1, ascending=False)
#
# TypeError: Series.sort_values() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given

# %%
retail.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom

# %%
retail['Revenue'] = retail.Quantity * retail.UnitPrice
retail.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00

# %%
# SELECT CustomerID, avg(Revenue), count(*) FROM retial GROUP BY CustomerID;
retail.groupby('CustomerID').aggregate({'Revenue': np.mean, 'CustomerID': np.size})
# Out:
# C:\Users\h4N7\AppData\Local\Temp\ipykernel_8060\922414830.py:2: FutureWarning: The provided callable <function mean at 0x0000019AC9217740> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   retail.groupby('CustomerID').aggregate({'Revenue': np.mean, 'CustomerID': np.size})
#                  Revenue  CustomerID
# CustomerID
# 12346       77183.600000           1
# 12347          23.681319         182
# 12348          57.975484          31
# 12349          24.076027          73
# 12350          19.670588          17
# ...                  ...         ...
# 18280          18.060000          10
# 18281          11.545714           7
# 18282          14.837500          12
# 18283           2.771005         756
# 18287          26.246857          70
#
# [4339 rows x 2 columns]

# %%
retail.groupby('CustomerID').aggregate({'Revenue': np.mean, 'CustomerID': np.size}). \
    rename(columns={'Revenue': 'RevenueAverage', 'CustomerID': 'CustomerIDCount'}). \
    sort_values('CustomerIDCount', ascending=False) #do sortowania po kolumnie trzeba je nazwać
# Out:
# C:\Users\h4N7\AppData\Local\Temp\ipykernel_8060\4064955286.py:1: FutureWarning: The provided callable <function mean at 0x0000019AC9217740> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   retail.groupby('CustomerID').aggregate({'Revenue': np.mean, 'CustomerID': np.size}). \
#             RevenueAverage  CustomerIDCount
# CustomerID
# 17841             5.223852             7847
# 14911            25.334694             5677
# 14096            12.749910             5111
# 12748             7.336756             4596
# 14606             4.502463             2700
# ...                    ...              ...
# 15940            35.800000                1
# 15823            15.000000                1
# 15802           451.420000                1
# 15753            79.200000                1
# 12346         77183.600000                1
#
# [4339 rows x 2 columns]

# %%
retail.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34

# %%
retail['InvoiceDateDay'] = retail.InvoiceDate.dt.day
retail.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
#
#    InvoiceDateDay
# 0               1
# 1               1

# %%
# SELECT InvoiceDateDay, sum(Revenue) FROM retail GROUP BY InvoiceDateDay;
results = retail.groupby('InvoiceDateDay').aggregate({'Revenue': np.sum})
results
# Out:
# C:\Users\h4N7\AppData\Local\Temp\ipykernel_8060\3242140834.py:2: FutureWarning: The provided callable <function sum at 0x0000019AC9216660> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   results = retail.groupby('InvoiceDateDay').aggregate({'Revenue': np.sum})
#                    Revenue
# InvoiceDateDay
# 1               286370.870
# 2               256858.750
# 3               285430.150
# 4               329347.220
# 5               354033.810
# 6               336759.840
# 7               376788.980
# 8               296747.450
# 9               460216.080
# 10              325106.180
# 11              345332.090
# 12              222496.570
# 13              252007.160
# 14              337574.550
# 15              304635.811
# 16              279384.030
# 17              333157.240
# 18              367947.890
# 19              249792.310
# 20              363689.280
# 21              325954.330
# 22              250304.000
# 23              249339.690
# 24              267594.910
# 25              228150.541
# 26              184091.902
# 27              224344.430
# 28              297424.870
# 29              167977.110
# 30              202865.820
# 31              149684.040

# %%
import seaborn as sns
sns.set()

results.plot(kind='bar')
# Out:
# <Axes: xlabel='InvoiceDateDay'>

# %%
# SELECT * FROM retail ORDER BY Quantity DESC LIMIT 5;
retail.nlargest(n=5, columns='Quantity')
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 421632    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197               SMALL POPCORN HOLDER      4300
#
#                InvoiceDate  UnitPrice CustomerID         Country   Revenue  \
# 540421 2011-12-09 09:15:00       2.08      16446  United Kingdom  168469.6
# 61619  2011-01-18 10:01:00       1.04      12346  United Kingdom   77183.6
# 502122 2011-11-25 15:57:00       0.00      13256  United Kingdom       0.0
# 421632 2011-10-27 12:26:00       0.21      12901  United Kingdom    1008.0
# 206121 2011-05-27 10:52:00       0.72      13135  United Kingdom    3096.0
#
#         InvoiceDateDay
# 540421               9
# 61619               18
# 502122              25
# 421632              27
# 206121              27

# %%
# SELECT * FROM retail ORDER BY Quantity LIMIT 5;
retail.nsmallest(n=5, columns='Quantity')
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 113    536381     71270                  PHOTO CLIP LINE         1
# 114    536381     22262            FELT EGG COSY CHICKEN         1
# 115    536381     22637            PIGGY BANK RETROSPOT          1
# 118    536381     21166       COOK WITH WINE METAL SIGN          1
# 120    536381    37444A  YELLOW BREAKFAST CUP AND SAUCER         1
#
#             InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 113 2010-12-01 09:41:00       1.25      15311  United Kingdom     1.25
# 114 2010-12-01 09:41:00       0.85      15311  United Kingdom     0.85
# 115 2010-12-01 09:41:00       2.55      15311  United Kingdom     2.55
# 118 2010-12-01 09:41:00       1.95      15311  United Kingdom     1.95
# 120 2010-12-01 09:41:00       2.95      15311  United Kingdom     2.95
#
#      InvoiceDateDay
# 113               1
# 114               1
# 115               1
# 118               1
# 120               1
